# %%
import pandas as pd

# %%
df = pd.read_excel("Base_de_dados.xlsx")

# %%
df.head(10)
# Out:
#   SalesOrderNumber                    OrderDate  ProductKey  ResellerKey  \
# 0          SO43897      Friday, August 25, 2017         235          312
# 1          SO43897      Friday, August 25, 2017         351          312
# 2          SO43897      Friday, August 25, 2017         348          312
# 3          SO43897      Friday, August 25, 2017         232          312
# 4          SO44544  Saturday, November 18, 2017         292          312
# 5          SO44544  Saturday, November 18, 2017         220          312
# 6          SO44544  Saturday, November 18, 2017         351          312
# 7          SO44544  Saturday, November 18, 2017         349          312
# 8          SO44544  Saturday, November 18, 2017         344          312
# 9          SO45321    Sunday, February 18, 2018         346          312
#
#    EmployeeKey  SalesTerritoryKey  Quantity  Unit Price    Sales     Cost  \
# 0          282                  4         2       28.84    57.68    63.45
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57851 entries, 0 to 57850
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   SalesOrderNumber   57851 non-null  object
#  1   OrderDate          57851 non-null  object
#  2   ProductKey         57851 non-null  int64
#  3   ResellerKey        57851 non-null  int64
#  4   EmployeeKey        57851 non-null  int64
#  5   SalesTerritoryKey  57851 non-null  int64
#  6   Quantity           57851 non-null  int64
#  7   Unit Price         57851 non-null  float64
#  8   Sales              57851 non-null  float64
#  9   Cost               57851 non-null  float64
#  10  Country            57851 non-null  object
#  11  Continent          57851 non-null  object
#  12  Product            57851 non-null  object
#  13  Color              52998 non-null  object
#  14  Subcategory        57851 non-null  object
#  15  Category           57851 non-null  object
# ...

# %%
df.describe()
# Out:
#          ProductKey   ResellerKey   EmployeeKey  SalesTerritoryKey  \
# count  57851.000000  57851.000000  57851.000000       57851.000000
# mean     408.636705    340.742978    286.131735           4.554424
# std      113.665645    205.493906      4.521832           2.412247
# min      212.000000      1.000000    272.000000           1.000000
# 25%      326.000000    166.000000    283.000000           3.000000
# 50%      401.000000    327.000000    285.000000           4.000000
# 75%      491.000000    514.000000    290.000000           6.000000
# max      606.000000    701.000000    296.000000          10.000000
#
#            Quantity    Unit Price         Sales          Cost
# count  57851.000000  57851.000000  57851.000000  57851.000000
# mean       3.528271    446.388513   1336.938293   1323.210932
# std        3.035766    521.880164   2150.408256   2169.787634
# min        1.000000      1.330000      1.370000      0.860000
# ...

# %%
df1 = df.copy()

# %%
df1.head()
# Out:
#   SalesOrderNumber                    OrderDate  ProductKey  ResellerKey  \
# 0          SO43897      Friday, August 25, 2017         235          312
# 1          SO43897      Friday, August 25, 2017         351          312
# 2          SO43897      Friday, August 25, 2017         348          312
# 3          SO43897      Friday, August 25, 2017         232          312
# 4          SO44544  Saturday, November 18, 2017         292          312
#
#    EmployeeKey  SalesTerritoryKey  Quantity  Unit Price    Sales     Cost  \
# 0          282                  4         2       28.84    57.68    63.45
# 1          282                  4         2     2024.99  4049.98  3796.19
# 2          282                  4         2     2024.99  4049.98  3796.19
# 3          282                  4         2       28.84    57.68    63.45
# 4          282                  4         2      818.70  1637.40  1413.62
#
#          Country      Continent                         Product   Color  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57851 entries, 0 to 57850
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   SalesOrderNumber   57851 non-null  object
#  1   OrderDate          57851 non-null  object
#  2   ProductKey         57851 non-null  int64
#  3   ResellerKey        57851 non-null  int64
#  4   EmployeeKey        57851 non-null  int64
#  5   SalesTerritoryKey  57851 non-null  int64
#  6   Quantity           57851 non-null  int64
#  7   Unit Price         57851 non-null  float64
#  8   Sales              57851 non-null  float64
#  9   Cost               57851 non-null  float64
#  10  Country            57851 non-null  object
#  11  Continent          57851 non-null  object
#  12  Product            57851 non-null  object
#  13  Color              52998 non-null  object
#  14  Subcategory        57851 non-null  object
#  15  Category           57851 non-null  object
# ...

# %%
df1 = df1.drop("Category",axis = 1)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57851 entries, 0 to 57850
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   SalesOrderNumber   57851 non-null  object
#  1   OrderDate          57851 non-null  object
#  2   ProductKey         57851 non-null  int64
#  3   ResellerKey        57851 non-null  int64
#  4   EmployeeKey        57851 non-null  int64
#  5   SalesTerritoryKey  57851 non-null  int64
#  6   Quantity           57851 non-null  int64
#  7   Unit Price         57851 non-null  float64
#  8   Sales              57851 non-null  float64
#  9   Cost               57851 non-null  float64
#  10  Country            57851 non-null  object
#  11  Continent          57851 non-null  object
#  12  Product            57851 non-null  object
#  13  Color              52998 non-null  object
#  14  Subcategory        57851 non-null  object
# dtypes: float64(3), int64(5), object(7)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57851 entries, 0 to 57850
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   SalesOrderNumber   57851 non-null  object
#  1   OrderDate          57851 non-null  object
#  2   ProductKey         57851 non-null  int64
#  3   ResellerKey        57851 non-null  int64
#  4   EmployeeKey        57851 non-null  int64
#  5   SalesTerritoryKey  57851 non-null  int64
#  6   Quantity           57851 non-null  int64
#  7   Unit Price         57851 non-null  float64
#  8   Sales              57851 non-null  float64
#  9   Cost               57851 non-null  float64
#  10  Country            57851 non-null  object
#  11  Continent          57851 non-null  object
#  12  Product            57851 non-null  object
#  13  Color              52998 non-null  object
#  14  Subcategory        57851 non-null  object
#  15  Category           57851 non-null  object
# ...

# %%
df_drop = df.copy()

# %%
df_drop = df_drop.dropna()

# %%
df_drop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 52998 entries, 0 to 57850
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   SalesOrderNumber   52998 non-null  object
#  1   OrderDate          52998 non-null  object
#  2   ProductKey         52998 non-null  int64
#  3   ResellerKey        52998 non-null  int64
#  4   EmployeeKey        52998 non-null  int64
#  5   SalesTerritoryKey  52998 non-null  int64
#  6   Quantity           52998 non-null  int64
#  7   Unit Price         52998 non-null  float64
#  8   Sales              52998 non-null  float64
#  9   Cost               52998 non-null  float64
#  10  Country            52998 non-null  object
#  11  Continent          52998 non-null  object
#  12  Product            52998 non-null  object
#  13  Color              52998 non-null  object
#  14  Subcategory        52998 non-null  object
#  15  Category           52998 non-null  object
# ...

# %%
df_fill = df.copy()

# %%
df_fill = df_fill.fillna(0)

# %%
df_fill.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57851 entries, 0 to 57850
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   SalesOrderNumber   57851 non-null  object
#  1   OrderDate          57851 non-null  object
#  2   ProductKey         57851 non-null  int64
#  3   ResellerKey        57851 non-null  int64
#  4   EmployeeKey        57851 non-null  int64
#  5   SalesTerritoryKey  57851 non-null  int64
#  6   Quantity           57851 non-null  int64
#  7   Unit Price         57851 non-null  float64
#  8   Sales              57851 non-null  float64
#  9   Cost               57851 non-null  float64
#  10  Country            57851 non-null  object
#  11  Continent          57851 non-null  object
#  12  Product            57851 non-null  object
#  13  Color              57851 non-null  object
#  14  Subcategory        57851 non-null  object
#  15  Category           57851 non-null  object
# ...

# %%
df.groupby(["Category","Subcategory"])["Sales"].sum().reset_index()
# Out:
#        Category        Subcategory        Sales
# 0   Accessories         Bike Racks    175365.60
# 1   Accessories  Bottles and Cages      6885.93
# 2   Accessories           Cleaners     10179.94
# 3   Accessories            Helmets    250209.76
# 4   Accessories    Hydration Packs     59218.45
# 5   Accessories              Locks     16249.00
# 6   Accessories              Pumps     13524.30
# 7   Accessories    Tires and Tubes       831.11
# 8         Bikes     Mountain Bikes  25690513.86
# 9         Bikes         Road Bikes  28681899.48
# 10        Bikes      Touring Bikes   9506980.82
# 11     Clothing         Bib-Shorts    167171.79
# 12     Clothing               Caps     30658.42
# 13     Clothing             Gloves    207372.85
# 14     Clothing            Jerseys    549933.91
# 15     Clothing             Shorts    317170.09
# 16     Clothing              Socks     23331.45
# 17     Clothing             Tights    202096.16
# 18     Clothing              Vests    207249.38
# ...

# %%
df.columns
# Out:
# Index(['SalesOrderNumber', 'OrderDate', 'ProductKey', 'ResellerKey',
#        'EmployeeKey', 'SalesTerritoryKey', 'Quantity', 'Unit Price', 'Sales',
#        'Cost', 'Country', 'Continent', 'Product', 'Color', 'Subcategory',
#        'Category'],
#       dtype='object')

# %%
df.query("Category == 'Bikes'").groupby('Subcategory')['Sales'].sum()
# Out:
# Subcategory
# Mountain Bikes    25690513.86
# Road Bikes        28681899.48
# Touring Bikes      9506980.82
# Name: Sales, dtype: float64

# %%
df_concat = df.copy()

# %%
df_final = pd.concat([df,df_concat])

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 115702 entries, 0 to 57850
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   SalesOrderNumber   115702 non-null  object
#  1   OrderDate          115702 non-null  object
#  2   ProductKey         115702 non-null  int64
#  3   ResellerKey        115702 non-null  int64
#  4   EmployeeKey        115702 non-null  int64
#  5   SalesTerritoryKey  115702 non-null  int64
#  6   Quantity           115702 non-null  int64
#  7   Unit Price         115702 non-null  float64
#  8   Sales              115702 non-null  float64
#  9   Cost               115702 non-null  float64
#  10  Country            115702 non-null  object
#  11  Continent          115702 non-null  object
#  12  Product            115702 non-null  object
#  13  Color              105996 non-null  object
#  14  Subcategory        115702 non-null  object
# ...

# %%
df.pivot_table(index=["Category","Subcategory"],columns="Country",values="Sales", aggfunc="sum")
# Out:
# Country                         Australia      Canada      France     Germany  \
# Category    Subcategory
# Accessories Bike Racks           10048.80    32485.20    19348.80    13270.80
#             Bottles and Cages      293.02     1263.57      614.31      782.68
#             Cleaners               443.61     1915.13     1007.25      841.06
#             Helmets               5373.44    55111.96    16402.37    10650.79
#             Hydration Packs       2591.91    11229.20     5608.28     6773.90
#             Locks                     NaN     4223.00     1050.00         NaN
#             Pumps                     NaN     3136.98     1073.90         NaN
#             Tires and Tubes          9.59      158.92       97.27       91.31
# Bikes       Mountain Bikes      100673.06  4524426.55  1007875.62   171688.44
#             Road Bikes            2932.02  5644479.07  1328946.83   171398.55
#             Touring Bikes      1065376.03  1051268.57  1169391.15  1119545.58
# ...

# %%
df['Country'].hist()
# Out:
# <Axes: >
